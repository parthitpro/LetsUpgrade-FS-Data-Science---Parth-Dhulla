# %%
import pandas as pd
import numpy as np
from numpy.random import randn, randint,uniform, sample
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.DataFrame(randn(89))
# Out:
#            0
# 0  -0.103555
# 1   0.178902
# 2  -0.346749
# 3   1.967984
# 4  -0.695471
# ..       ...
# 84 -0.864300
# 85  0.146382
# 86 -0.321794
# 87  0.392879
# 88  0.302266
#
# [89 rows x 1 columns]

# %%
df= pd.DataFrame(randn(100), index=pd.date_range('01-03-2022',periods=100),columns=['value'])

# %%
df.tail()
# Out:
#                value
# 2022-04-08  0.918438
# 2022-04-09 -0.669470
# 2022-04-10 -0.032567
# 2022-04-11 -0.153093
# 2022-04-12 -0.999893

# %%
de = pd.Series(randn(99),index=pd.date_range('01-03-2022',periods=99))

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
de.plot()
# Out:
# <AxesSubplot:>

# %%
x = np.linspace(0,10,50)
y = np.sin(x)

# %%
plt.plot(x,y,color='g',marker='*')

# %%
x=np.linspace(-50,50,100)
y=x**2

# %%
plt.plot(x,y,color='g',marker='*')

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
ax= iris.plot(figsize=(15,8),title='iris dataset')

# %%
ax= iris.plot(figsize=(15,8))

# %%
df =iris.drop(['species'],axis=1)

# %%
iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
x=[1,2,3,4,5,6]
y=[1,4,6,8,10,12]

# %%
x2=np.arange(0,4,)

# %%
x2
# Out:
# array([0, 1, 2, 3])

# %%
x2**2
# Out:
# array([0, 1, 4, 9])

# %%
plt.plot(x,y,'r^--',label='2x')
plt.plot(x2,x2**2,'g',label='x^2')
plt.legend()
plt.show()

# %% [markdown]
# Bar plot

# %% [markdown]
# A bar plot or graph is a chart that present categoroical data with rectangulars bars with heights or lengths proportional to the values that they represent

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot()
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
bars= plt.bar(df.columns,df.iloc[3])
patterns=['/','O','+']
bars[0].set_hatch('/')
bars[1].set_hatch('*')
bars[2].set_hatch('-')
bars[3].set_hatch('+')

# %% [markdown]
# Histogram
#
# A histogram is a graphical representation of tabulated frequencies, shown as adjacent rectangles, erected over discrete intervals (bins), with an area equal to the frequency of the observations in the interval. ... The total area of the histogram is equal to the number of data.

# %%
iris['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
de= iris.drop(columns=['species'])

# %%
de
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
de.hist(color='g')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# Scatter
#
# The scatter() fuction plots one dots for each onbservation . it needs two arrays of the same length, one for the vales if the x-axis ,
# and one for the values on the y-axis

# %%
iris.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.plot.scatter(x='sepal_width',y='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>
