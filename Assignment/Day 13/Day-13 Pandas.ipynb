# %%
import pandas as pd
import numpy as np

# %%
df1={
    'fruit':['apple','apples','orange','orange','mangoes','mangoes','mangoes','banana'],
    'month':['Nov','Dec','jan','Feb','Mar','Apr','May','June'],
    'Sale':[250,50,300,500,400,270,640,700]
}

# %%
df1= pd.DataFrame(df1)

# %%
df1
# Out:
#      fruit month  Sale
# 0    apple   Nov   250
# 1   apples   Dec    50
# 2   orange   jan   300
# 3   orange   Feb   500
# 4  mangoes   Mar   400
# 5  mangoes   Apr   270
# 6  mangoes   May   640
# 7   banana  June   700

# %%
x=df1.groupby('fruit')

# %%
x.mean()
# Out:
#                Sale
# fruit
# apple    250.000000
# apples    50.000000
# banana   700.000000
# mangoes  436.666667
# orange   400.000000

# %%
x.median()
# Out:
#           Sale
# fruit
# apple    250.0
# apples    50.0
# banana   700.0
# mangoes  400.0
# orange   400.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fruit   8 non-null      object
#  1   month   8 non-null      object
#  2   Sale    8 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
x.sum()
# Out:
#          Sale
# fruit
# apple     250
# apples     50
# banana    700
# mangoes  1310
# orange    800

# %%
df1.describe()
# Out:
#              Sale
# count    8.000000
# mean   388.750000
# std    216.625912
# min     50.000000
# 25%    265.000000
# 50%    350.000000
# 75%    535.000000
# max    700.000000

# %%
x.describe()
# Out:
#          Sale
#         count        mean         std    min    25%    50%    75%    max
# fruit
# apple     1.0  250.000000         NaN  250.0  250.0  250.0  250.0  250.0
# apples    1.0   50.000000         NaN   50.0   50.0   50.0   50.0   50.0
# banana    1.0  700.000000         NaN  700.0  700.0  700.0  700.0  700.0
# mangoes   3.0  436.666667  187.705443  270.0  335.0  400.0  520.0  640.0
# orange    2.0  400.000000  141.421356  300.0  350.0  400.0  450.0  500.0

# %%
df= pd.read_csv('D:/Assignment/dataset/Titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.Name
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df[['Name','Age']]
# Out:
#                                              Name   Age
# 0                                Kelly, Mr. James  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0
# 2                       Myles, Mr. Thomas Francis  62.0
# 3                                Wirz, Mr. Albert  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..                                            ...   ...
# 413                            Spector, Mr. Woolf   NaN
# 414                  Oliva y Ocana, Dona. Fermina  39.0
# 415                  Saether, Mr. Simon Sivertsen  38.5
# 416                           Ware, Mr. Frederick   NaN
# 417                      Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Since the test data doesnot have Survied columns , so we  have to merge the dataset

# %%
gender = pd.read_csv('D:/Assignment/dataset/gender_submission.csv')

# %%
gender
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
c=pd.merge_ordered(df,gender)

# %%
c.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
c['Survived'].value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
c.Sex.value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
table= pd.pivot_table(c,index=['Sex'],values=['Age'], aggfunc=np.mean)

# %%
table
# Out:
#               Age
# Sex
# female  30.272362
# male    30.272732

# %%
c.rename(columns={'Sex':'Gender'},inplace=True)

# %%
c
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#      Gender   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
c[(c.Gender=='male')]
# Out:
#      PassengerId  Pclass                          Name Gender   Age  SibSp  \
# 0            892       3              Kelly, Mr. James   male  34.5      0
# 2            894       2     Myles, Mr. Thomas Francis   male  62.0      0
# 3            895       3              Wirz, Mr. Albert   male  27.0      0
# 5            897       3    Svensson, Mr. Johan Cervin   male  14.0      0
# 7            899       2  Caldwell, Mr. Albert Francis   male  26.0      1
# ..           ...     ...                           ...    ...   ...    ...
# 407         1299       1    Widener, Mr. George Dunton   male  50.0      1
# 413         1305       3            Spector, Mr. Woolf   male   NaN      0
# 415         1307       3  Saether, Mr. Simon Sivertsen   male  38.5      0
# 416         1308       3           Ware, Mr. Frederick   male   NaN      0
# 417         1309       3      Peter, Master. Michael J   male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  Survived
# ...

# %%
import sklearn

# %%
from sklearn.datasets import load_boston

# %%
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
bodata= load_boston()

# %%
bodata
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
bodata_df = pd.DataFrame(bodata.data, columns=bodata.feature_names)

# %%
bodata_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
bodata_df.shape
# Out:
# (506, 13)

# %%
bodata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
bodata_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
bodata_df.count()
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# dtype: int64

# %%
bodata_df.mean()
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# dtype: float64

# %%
bodata_df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
bodata_df['Price']= bodata.target

# %%
bodata_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# ...

# %%
bodata_df.drop(index=0,axis=0)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 1    0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# 5    0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Price
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# ...

# %%
bodata_df.drop(columns=['ZN','CHAS'],axis=1)
# Out:
#         CRIM  INDUS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO       B  \
# 0    0.00632   2.31  0.538  6.575  65.2  4.0900  1.0  296.0     15.3  396.90
# 1    0.02731   7.07  0.469  6.421  78.9  4.9671  2.0  242.0     17.8  396.90
# 2    0.02729   7.07  0.469  7.185  61.1  4.9671  2.0  242.0     17.8  392.83
# 3    0.03237   2.18  0.458  6.998  45.8  6.0622  3.0  222.0     18.7  394.63
# 4    0.06905   2.18  0.458  7.147  54.2  6.0622  3.0  222.0     18.7  396.90
# ..       ...    ...    ...    ...   ...     ...  ...    ...      ...     ...
# 501  0.06263  11.93  0.573  6.593  69.1  2.4786  1.0  273.0     21.0  391.99
# 502  0.04527  11.93  0.573  6.120  76.7  2.2875  1.0  273.0     21.0  396.90
# 503  0.06076  11.93  0.573  6.976  91.0  2.1675  1.0  273.0     21.0  396.90
# 504  0.10959  11.93  0.573  6.794  89.3  2.3889  1.0  273.0     21.0  393.45
# 505  0.04741  11.93  0.573  6.030  80.8  2.5050  1.0  273.0     21.0  396.90
#
#      LSTAT  Price
# 0     4.98   24.0
# ...

# %%
bodata_df.iloc[51]
# Out:
# CRIM         0.04337
# ZN          21.00000
# INDUS        5.64000
# CHAS         0.00000
# NOX          0.43900
# RM           6.11500
# AGE         63.00000
# DIS          6.81470
# RAD          4.00000
# TAX        243.00000
# PTRATIO     16.80000
# B          393.97000
# LSTAT        9.43000
# Price       20.50000
# Name: 51, dtype: float64

# %%
bodata_df.iloc[:,-1]
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: Price, Length: 506, dtype: float64
