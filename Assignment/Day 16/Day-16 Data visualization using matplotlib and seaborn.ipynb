# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter('ignore')

# %%
yiels_mangoes = [0.67,0.78,0.80,0.90,0.93,0.99]
years = [2010,2015,2020,2025,2030,2035]

# %%
plt.plot(yiels_mangoes,years)
plt.show()

# %%
yiels_mangoes = random.sample(range(1,20),6)
years = [2010,2015,2020,2025,2030,2035]
plt.plot(yiels_mangoes,years)
plt.show()

# %%
yiels_mangoes
# Out:
# [16, 13, 1, 11, 2, 4]

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.scatterplot(x=iris['petal_length'],y=iris['petal_width'],hue=iris['species'])
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['sepal_width'],hue=iris['species'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['sepal_width'],hue=iris['species'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.set_style('whitegrid')
sns.pairplot(iris,hue='species',size=3)
plt.show()

# %%
plt.hist(iris['sepal_length'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(iris['petal_length'],bins=10,color='g',rwidth=0.75)
plt.show()

# %%
## Pie chart
expenses_labels=['rent', 'food', 'internet','car', 'misc']
expenses_values=[1500, 5000, 2000, 3000, 2000]

# %%
plt.pie(expenses_values,labels=expenses_labels,radius=1.35,startangle=100,shadow=True,explode=[0,0.1,0.2,0,0.21])
plt.show()

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=800)

# %%
plt.figure(figsize=(10,12))
sns.FacetGrid(iris,hue='species').map(sns.distplot,'petal_length').add_legend()
plt.show()

# %%
ac= sns.load_dataset('tips')

# %%
ac
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='sex',y='total_bill',data=ac)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='smoker',y='tip',data=ac,)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>
